# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.interpolate import CubicSpline

# %% [markdown]
# Single-Instrument Notes

# %%
# Read the CSV file
data = pd.read_csv("./plot_data/violin_test.csv")  # change to your filename
x = data.iloc[:, 0].values
y = data.iloc[:, 1].values

# Create cubic spline interpolation
cs = CubicSpline(x, y)

# Generate smooth curve
x_smooth = np.linspace(min(x), max(x), 500)
y_smooth = cs(x_smooth)

# Plot
plt.figure(figsize=(8, 5))
plt.scatter(x, y, color='red', label='Data Points')
plt.plot(x_smooth, y_smooth, color='blue', linewidth=2, label='Cubic Spline')
plt.title('Cubic Interpolation')
plt.xlabel('X')
plt.ylabel('Y')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# Single-Instrument Chords

# %% [markdown]
# Multiple-Instrument Chords
